# %% [markdown]
# # Prevendo o Nível de Satisfação dos Clientes do Santander
# ## Leonara Alves

# %% [markdown]
# #### Objetivo: Acurácia de pelo menos 70%.

# %%
# Leitura de Pacotes
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import Normalizer
from sklearn import model_selection
from sklearn.metrics import classification_report
from pandas.tools.plotting import scatter_matrix
from sklearn.decomposition import PCA               # PCA
from sklearn.preprocessing import MinMaxScaler      # escala
from sklearn.preprocessing import StandardScaler    # padronização
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import ExtraTreesClassifier   
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import GridSearchCV
# %matplotlib inline

# %%
# Lendo a base de dados
dataset_train = pd.read_csv("data/train.csv", index_col = 'ID')
dataset_test = pd.read_csv("data/test.csv", index_col = 'ID')

# %%
# Visualização dos dados
dataset_train.head(10)
# Out:
#     var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# ID
# 1      2     23                 0.0                      0.0
# 3      2     34                 0.0                      0.0
# 4      2     23                 0.0                      0.0
# 8      2     37                 0.0                    195.0
# 10     2     39                 0.0                      0.0
# 13     2     23                 0.0                      0.0
# 14     2     27                 0.0                      0.0
# 18     2     26                 0.0                      0.0
# 20     2     45                 0.0                      0.0
# 23     2     25                 0.0                      0.0
#
#     imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# ID
# 1                       0.0                      0.0                      0.0
# 3                       0.0                      0.0                      0.0
# ...

# %%
# Remove colunas constantes (std = 0)
remove = []
for col in dataset_train.columns:
    if dataset_train[col].std() == 0:
        remove.append(col)

dataset_train.drop(remove, axis = 1, inplace = True)
dataset_test.drop(remove, axis = 1, inplace = True)

# %%
# Remove colunas duplicadas
remove = []
cols = dataset_train.columns
for i in range(len(cols)-1):
    v = dataset_train[cols[i]].values
    for j in range(i+1,len(cols)):
        if np.array_equal(v,dataset_train[cols[j]].values):
            remove.append(cols[j])

dataset_train.drop(remove, axis = 1, inplace = True)
dataset_test.drop(remove, axis = 1, inplace = True)

# %%
# Distribuição das classes
dataset_train.groupby('TARGET').size()
# Out:
# TARGET
# 0    73012
# 1     3008
# dtype: int64

# %%
# Descrição dos dados
dataset_train.describe()
# Out:
#                 var3         var15  imp_ent_var16_ult1  \
# count   76020.000000  76020.000000        76020.000000
# mean    -1523.199277     33.212865           86.208265
# std     39033.462364     12.956486         1614.757313
# min   -999999.000000      5.000000            0.000000
# 25%         2.000000     23.000000            0.000000
# 50%         2.000000     28.000000            0.000000
# 75%         2.000000     40.000000            0.000000
# max       238.000000    105.000000       210000.000000
#
#        imp_op_var39_comer_ult1  imp_op_var39_comer_ult3  \
# count             76020.000000             76020.000000
# mean                 72.363067               119.529632
# std                 339.315831               546.266294
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# ...

# %%
# Tipos de Dados
print(dataset_train.dtypes)
# Out:
# var3                               int64
# var15                              int64
# imp_ent_var16_ult1               float64
# imp_op_var39_comer_ult1          float64
# imp_op_var39_comer_ult3          float64
# imp_op_var40_comer_ult1          float64
# imp_op_var40_comer_ult3          float64
# imp_op_var40_efect_ult1          float64
# imp_op_var40_efect_ult3          float64
# imp_op_var40_ult1                float64
# imp_op_var41_comer_ult1          float64
# imp_op_var41_comer_ult3          float64
# imp_op_var41_efect_ult1          float64
# imp_op_var41_efect_ult3          float64
# imp_op_var41_ult1                float64
# imp_op_var39_efect_ult1          float64
# imp_op_var39_efect_ult3          float64
# imp_op_var39_ult1                float64
# imp_sal_var16_ult1               float64
# ind_var1_0                         int64
# ind_var1                           int64
# ind_var5_0                         int64
# ind_var5                           int64
# ...

# %% [markdown]
# ## Visualização dos Dados

# %%
# Correlação
correlations = dataset_train.corr(method = 'pearson');correlations
# Out:
#                                    var3     var15  imp_ent_var16_ult1  \
# var3                           1.000000 -0.004452            0.001868
# var15                         -0.004452  1.000000            0.043722
# imp_ent_var16_ult1             0.001868  0.043722            1.000000
# imp_op_var39_comer_ult1        0.005989  0.094762            0.041221
# imp_op_var39_comer_ult3        0.006817  0.101177            0.034879
# imp_op_var40_comer_ult1        0.001518  0.042754            0.009896
# imp_op_var40_comer_ult3        0.001690  0.048512            0.009377
# imp_op_var40_efect_ult1        0.000530  0.008805            0.000592
# imp_op_var40_efect_ult3        0.000611  0.009678            0.002510
# imp_op_var40_ult1              0.001311  0.035884            0.011502
# imp_op_var41_comer_ult1        0.005916  0.088145            0.040879
# imp_op_var41_comer_ult3        0.006764  0.093354            0.034387
# ...

# %%
# Pegando as correlações com a variável target
corr_target = correlations.iloc[-1,:];corr_target.head(10)
# Out:
# var3                       0.004475
# var15                      0.101322
# imp_ent_var16_ult1        -0.000017
# imp_op_var39_comer_ult1    0.010353
# imp_op_var39_comer_ult3    0.003517
# imp_op_var40_comer_ult1    0.003119
# imp_op_var40_comer_ult3   -0.000358
# imp_op_var40_efect_ult1    0.019221
# imp_op_var40_efect_ult3    0.019965
# imp_op_var40_ult1          0.003087
# Name: TARGET, dtype: float64

# %%
# Salvando as correlações entre -0.05 e 0.05
aux = []
for i in range(0,len(corr_target)):
    if(corr_target[i] > -0.05) and (corr_target[i] < 0.05):
        aux.append(corr_target.index[i])

# %%
# Retirando as variaveis sem correlacao com a variavel resposta
dataset_train = dataset_train.drop(aux, axis = 1)
dataset_test = dataset_test.drop(aux, axis = 1)

# %%
# Gráfico de Correlação
sns.set(style = "white")

# Compute the correlation matrix
corr = dataset_train.corr(method = 'pearson')

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap = True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %%
# Histogramas
dataset_train.hist(figsize = (15,10), color = "lightcoral")
plt.show()

# %% [markdown]
# ### Preparação dos Dados

# %%
# Balanceamento das observações
array = dataset_train.values
array_test = dataset_test.values

# Separando o array em componentes de input e output
X = array[:,0:(dataset_train.shape[1]-1)]
Y = array[:,(dataset_train.shape[1]-1)]
Y = Y.astype('int')

sm = SMOTE(random_state = 7)
X, Y = sm.fit_resample(X, Y)
print('Resampled dataset shape %s' % Counter(Y))
# Out:
# Resampled dataset shape Counter({0: 73012, 1: 73012})

# %%
# Normalizando os dados (comprimento igual a 1)

# Gerando os dados normalizados 
scaler = Normalizer().fit(X)
normalizedX = scaler.transform(X)

normalizedX_test = scaler.transform(array_test)

# %%
# Transformando os dados para a mesma escala (entre 0 e 1)

# Gerando a nova escala
scaler = MinMaxScaler(feature_range = (0, 1)).fit(normalizedX)
rescaledX = scaler.transform(normalizedX)

rescaledX_test = scaler.transform(normalizedX_test)

# %%
# Adicionando os dados normalizados para o dataset original

# Dados de treino
dataset_train_normalizes = pd.DataFrame(rescaledX)
dataset_train_normalizes['target'] = Y.astype(int)

dataset_train_normalizes.head(10)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.185197  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.986595  0.000000  0.215347  0.155093  0.000000  0.192685  0.118983
# 2  0.184645  0.083870  0.072799  0.052430  0.083870  0.065138  0.040223
# 3  0.954307  0.220900  0.191741  0.414276  0.220900  0.171563  0.317821
# 4  0.986753  0.000000  0.187767  0.135230  0.000000  0.168007  0.103744
# 5  0.185197  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.961096  0.304755  0.264527  0.190512  0.304755  0.236689  0.146156
# 7  0.965195  0.317755  0.275811  0.198639  0.317755  0.246786  0.152390
# 8  0.382664  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9  0.962505  0.329592  0.286086  0.206039  0.329592  0.255979  0.158067
#
#           7         8         9  target
# 0  0.000000  0.975300  0.000000       0
# 1  0.000000  0.087223  0.082699       0
# 2  0.072799  0.973042  0.083870       0
# ...

# %% [markdown]
# ### Feature Extraction

# %%
# Feature Extraction (PCA)

# Seleção de atributos (5 componentes)
pca = PCA(n_components = 5)
fit = pca.fit(rescaledX)

#fit_test = pca.fit(array_test)

# Sumarizando os componentes
print("Variância: %s" % fit.explained_variance_ratio_)
print(fit.components_)
# Out:
# Variância: [0.89927229 0.06000143 0.02724143 0.00504922 0.00369925]
# [[ 0.53891025  0.16990272  0.16318916  0.18520012  0.17111756  0.15515009
#    0.14552775  0.16527806 -0.70025001  0.16607532]
#  [-0.31403926  0.44380714  0.28290281  0.13501808  0.44805799  0.25016469
#    0.10172255  0.31594934  0.31491209  0.36533719]
#  [-0.23169181 -0.22802628  0.02396416  0.69138485 -0.22253534  0.07691157
#    0.56636931  0.06009796  0.00442232 -0.18945381]
#  [-0.01846812 -0.27806188  0.36775294 -0.22890729 -0.24346095  0.52567114
#   -0.18633568  0.50637994  0.00333279 -0.32854776]
#  [-0.74310141  0.03226845 -0.06584901 -0.14740065  0.04919554 -0.00304053
#   -0.08575093 -0.04157339 -0.63936931 -0.01979587]]

# %% [markdown]
# ### Seleção do Modelo Preditivo

# %%
# Aplicando o PCA aos datasets
pca = PCA(n_components = 5).fit(rescaledX)
newdf_train = pca.transform(rescaledX)
newdf_test = pca.transform(rescaledX_test) 

# Gerando novos datasets
features_train = pd.DataFrame(newdf_train)
features_test = pd.DataFrame(newdf_test)

# %%
# *************** Esta célula leva alguns minutos para ser executada **********

# Criando os modelos

modelos = []
modelos.append(('RF', RandomForestClassifier(n_estimators = 100)))
modelos.append(('ET', ExtraTreesClassifier(n_estimators = 100)))
modelos.append(('GB', GradientBoostingClassifier(n_estimators = 100)))
modelos.append(('AdaB', AdaBoostClassifier(n_estimators = 100)))
modelos.append(('LR', LogisticRegression(solver = 'lbfgs')))
modelos.append(('XGB', XGBClassifier())) 
modelos.append(('NB', GaussianNB()))
modelos.append(('KNN', KNeighborsClassifier()))
modelos.append(('CART', DecisionTreeClassifier()))

# Criando lista para os resultados e nomes dos modelos
resultados = []
nomes = []

# Percorrendo cada um dos modelos
for nome, modelo in modelos:
    kfold = model_selection.KFold(n_splits = 10, random_state = 7)
    cross_val_result = model_selection.cross_val_score(modelo, 
                                                        features_train, 
                                                        Y, 
                                                        cv = kfold, 
                                                        scoring = 'accuracy')
    resultados.append(cross_val_result)
    nomes.append(nome)
    texto = "%s: %f (%f)" % (nome, cross_val_result.mean(), cross_val_result.std())
    print(texto)
# Out:
# RF: 0.755582 (0.018682)
# ET: 0.755677 (0.015868)
# GB: 0.674423 (0.022276)
# AdaB: 0.661782 (0.013931)
# LR: 0.594341 (0.019875)
# XGB: 0.669191 (0.020113)
# NB: 0.621022 (0.022306)
# KNN: 0.714944 (0.044530)
# CART: 0.753719 (0.016766)

# %%
# Comparando os modelos criados
fig = plt.figure()
fig.suptitle('Comparando Algoritmos Ensemble')
ax = fig.add_subplot(111)
plt.boxplot(resultados)
ax.set_xticklabels(nomes)
plt.show()

# %% [markdown]
# ### Otimização dos Parâmetros

# %%
# Embora o ExtraTreesClassifier tenha apresentado a menor taxa de erro entre os métodos ensemble, podemos ainda otimizá-lo
# com o ajuste dos parâmetros.

# O número padrão de estimadores com o GBM é 100 (número de árvores). Vamos testar outros valores para o estimador.
valores_grid = dict(n_estimators = np.array([30,50,100,200,300,400]))

# Criando o modelo
modelo = ExtraTreesClassifier(random_state = 7)

# Definindo k
kfold = model_selection.KFold(10, True, random_state = 7)

# Testando a combinação de parâmetros
grid = GridSearchCV(estimator = modelo, param_grid = valores_grid, cv = kfold, scoring = 'neg_mean_squared_error')
grid_result = grid.fit(features_train, Y)

# Print do resultado

mean_score = [mean for mean in grid_result.cv_results_['mean_test_score']]

# Criando uma lista com desvio padrão dos scores
std_score = [std for std in grid_result.cv_results_['std_test_score']]

# Criando uma lista com os parametros utilizados
params = [params for params in grid_result.cv_results_['params']]

# Variável para indicar a linha da lista
i = 0

print("Melhor MSE: %f utilizando %s" % (grid_result.best_score_, grid_result.best_params_))
for param in params:
    print("%f (%f) with: %r" % (mean_score[i],std_score[i],param))
    i = i +1;
# Out:
# Melhor MSE: -0.208945 utilizando {'n_estimators': 200}
# -0.209151 (0.002707) with: {'n_estimators': 30}
# -0.209068 (0.002768) with: {'n_estimators': 50}
# -0.208986 (0.002710) with: {'n_estimators': 100}
# -0.208945 (0.002795) with: {'n_estimators': 200}
# -0.209007 (0.002813) with: {'n_estimators': 300}
# -0.208979 (0.002719) with: {'n_estimators': 400}

# %% [markdown]
# ## Previsão

# %%
# Preparando a versão final do modelo
modelo = ExtraTreesClassifier(n_estimators = 200)
modelo.fit(features_train, Y)
previsoes = modelo.predict_proba(features_test)

# %%
dataset_test_submission = pd.read_csv("data/test.csv", index_col = 'ID')
dataset_test_submission['TARGET'] = previsoes[:,1]
Submission = dataset_test_submission['TARGET']
Submission = pd.DataFrame(Submission);Submission.head(10)
# Out:
#       TARGET
# ID
# 2   0.402116
# 5   0.583333
# 6   0.000000
# 7   0.345045
# 9   0.036088
# 11  0.851641
# 12  0.021641
# 15  0.742988
# 16  0.721311
# 17  0.421875

# %%
Submission.mean()
# Out:
# TARGET    0.29906
# dtype: float64

# %% [markdown]
# ### Salvando os resultados

# %%
Submission.to_csv('results/Submission.csv', header = True)
